# %%
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("heights.csv")
df.head(3)
# Out:
#        name  height
# 0     Aarav    5.45
# 1   Deepika    5.61
# 2  Abhishek    5.65

# %%
df.shape
# Out:
# (1000, 2)

# %%
mean = round(df.height.mean(),2)
std = round(df.height.std(),2)

mean, std
# Out:
# (np.float64(5.61), np.float64(0.33))

# %%
sns.histplot(df.height, kde = True)

plt.axvline(mean, color = 'black' , linestyle = 'dashed', linewidth = 1)

# one stadard deviation
plt.axvline(mean + std, color='r', linestyle='dashed', linewidth=1)
plt.axvline(mean - std, color='r', linestyle='dashed', linewidth=1)

# %%
df.describe()
# Out:
#             height
# count  1000.000000
# mean      5.609440
# std       0.327504
# min       4.650000
# 25%       5.360000
# 50%       5.620000
# 75%       5.850000
# max       6.630000

# %%
left = round(mean - std,2)
right = round(mean + std,2)

left, right
# Out:
# (np.float64(5.28), np.float64(5.94))
